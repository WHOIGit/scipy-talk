# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %%
def cdist(I, J):
    i, j = np.mgrid[:I.shape[0],:J.shape[0]]
    return np.sqrt(np.sum((I[i] - J[j])**2,axis=2))

# %%
I, J = np.random.uniform(size=(2,10))
IJ = np.vstack((I,J)).T

plt.figure(figsize=(7,7))
plt.gca().set_aspect('equal')
plt.scatter(I,J)

# %%
D = cdist(IJ,IJ)
D
# Out:
# array([[ 0.        ,  0.75534817,  0.29067002,  0.2750999 ,  0.69146658,
#          0.67209808,  0.84801998,  0.82972674,  0.43807396,  0.90140236],
#        [ 0.75534817,  0.        ,  0.53821699,  0.72209373,  0.27217381,
#          0.49983211,  0.26119519,  0.24004319,  0.3831652 ,  0.40891457],
#        [ 0.29067002,  0.53821699,  0.        ,  0.45257484,  0.5751654 ,
#          0.65540058,  0.70356002,  0.55851859,  0.16567385,  0.61385609],
#        [ 0.2750999 ,  0.72209373,  0.45257484,  0.        ,  0.56267631,
#          0.46258587,  0.72595714,  0.87002578,  0.53348017,  0.98399116],
#        [ 0.69146658,  0.27217381,  0.5751654 ,  0.56267631,  0.        ,
#          0.23023434,  0.16355704,  0.50823844,  0.47351823,  0.67396379],
#        [ 0.67209808,  0.49983211,  0.65540058,  0.46258587,  0.23023434,
#          0.        ,  0.34774159,  0.73036363,  0.60589158,  0.8918069 ],
#        [ 0.84801998,  0.26119519,  0.70356002,  0.72595714,  0.16355704,
#          0.34774159,  0.        ,  0.49260422,  0.5781416 ,  0.6616397 ],
#        [ 0.82972674,  0.24004319,  0.55851859,  0.87002578,  0.50823844,
#          0.73036363,  0.49260422,  0.        ,  0.39509733,  0.16947623],
#        [ 0.43807396,  0.3831652 ,  0.16567385,  0.53348017,  0.47351823,
#          0.60589158,  0.5781416 ,  0.39509733,  0.        ,  0.46687531],
#        [ 0.90140236,  0.40891457,  0.61385609,  0.98399116,  0.67396379,
#          0.8918069 ,  0.6616397 ,  0.16947623,  0.46687531,  0.        ]])

# %%
nn_ix = np.argsort(D,axis=1)
nn_ix
# Out:
# array([[0, 3, 2, 8, 5, 4, 1, 7, 6, 9],
#        [1, 7, 6, 4, 8, 9, 5, 2, 3, 0],
#        [2, 8, 0, 3, 1, 7, 4, 9, 5, 6],
#        [3, 0, 2, 5, 8, 4, 1, 6, 7, 9],
#        [4, 6, 5, 1, 8, 7, 3, 2, 9, 0],
#        [5, 4, 6, 3, 1, 8, 2, 0, 7, 9],
#        [6, 4, 1, 5, 7, 8, 9, 2, 3, 0],
#        [7, 9, 1, 8, 6, 4, 2, 5, 0, 3],
#        [8, 2, 1, 7, 0, 9, 4, 3, 6, 5],
#        [9, 7, 1, 8, 2, 6, 4, 5, 0, 3]])

# %%
k=3
knn_ix = nn_ix[:,:k]
knn_ix
# Out:
# array([[0, 3, 2],
#        [1, 7, 6],
#        [2, 8, 0],
#        [3, 0, 2],
#        [4, 6, 5],
#        [5, 4, 6],
#        [6, 4, 1],
#        [7, 9, 1],
#        [8, 2, 1],
#        [9, 7, 1]])

# %%
row, _ = np.mgrid[:IJ.shape[0],:k]
row
# Out:
# array([[0, 0, 0],
#        [1, 1, 1],
#        [2, 2, 2],
#        [3, 3, 3],
#        [4, 4, 4],
#        [5, 5, 5],
#        [6, 6, 6],
#        [7, 7, 7],
#        [8, 8, 8],
#        [9, 9, 9]])

# %%
knn_dist = D[row, knn_ix]
knn_dist
# Out:
# array([[ 0.        ,  0.2750999 ,  0.29067002],
#        [ 0.        ,  0.24004319,  0.26119519],
#        [ 0.        ,  0.16567385,  0.29067002],
#        [ 0.        ,  0.2750999 ,  0.45257484],
#        [ 0.        ,  0.16355704,  0.23023434],
#        [ 0.        ,  0.23023434,  0.34774159],
#        [ 0.        ,  0.16355704,  0.26119519],
#        [ 0.        ,  0.16947623,  0.24004319],
#        [ 0.        ,  0.16567385,  0.3831652 ],
#        [ 0.        ,  0.16947623,  0.40891457]])

# %%
def knn(query_pts, pts, k=3):
    # brute force k nearest neighbors
    D = cdist(query_pts, pts)
    knn_ix = np.argsort(D,axis=1)[:,:k]
    row, _ = np.mgrid[:query_pts.shape[0],:k]
    knn_dist = D[row, knn_ix]
    return knn_dist, knn_ix

# %%
from scipy import stats

# now make a grid
resolution = 100
m = np.linspace(0, 1, resolution)
n = np.linspace(0, 1, resolution)
M, N = np.meshgrid(m,n)
MN = np.dstack((M,N)).reshape(-1,2)

# now find the k nearest neighbors for each grid point
dist, nabe = knn(MN,IJ,k=1)

dist_img = dist.reshape((resolution,resolution))

plt.figure(figsize=(7,7))
plt.gca().set_aspect('equal')
plt.scatter(I, J, c='black')
plt.imshow(0-dist_img,origin='lower',cmap='gray',extent=[0, 1, 0, 1])

# %%
from skimage.color import label2rgb

label_img = nabe.reshape((resolution,resolution))
colors = np.random.uniform(low=0.25,size=(np.max(label_img)+1,3))

plt.figure(figsize=(7,7))
plt.gca().set_aspect('equal')
plt.scatter(I, J, c='black')
plt.imshow(label2rgb(label_img,colors=colors),interpolation='nearest',origin='lower',extent=[0, 1, 0, 1])
